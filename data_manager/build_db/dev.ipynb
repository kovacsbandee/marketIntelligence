# %%
import os
from dotenv import load_dotenv

import yfinance as yf
import pandas as pd

load_dotenv()
ALPHA_API_KEY = os.getenv("ALPHA_API_KEY")

# %%
# Out:
# 'GC8BSW78J9GUAF7E'

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
symbol = "IBM"
month = "2024-11"
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={symbol}&interval=1min&month={month}&outputsize=full&apikey={ALPHA_API_KEY}'
r = requests.get(url)
data = r.json()

# %%
data_df = pd.DataFrame.from_dict(data=data["Time Series (1min)"], orient='index')
data_df.columns = ['open', 'high', 'low', 'close', 'volume']
data_df.index = pd.to_datetime(data_df.index)
data_df.sort_index(ascending=True, axis=0, inplace=True)
data_df.index
# Out:
# DatetimeIndex(['2024-11-01 04:01:00', '2024-11-01 04:03:00',
#                '2024-11-01 04:04:00', '2024-11-01 04:05:00',
#                '2024-11-01 04:06:00', '2024-11-01 04:13:00',
#                '2024-11-01 04:14:00', '2024-11-01 04:15:00',
#                '2024-11-01 04:17:00', '2024-11-01 04:26:00',
#                ...
#                '2024-11-29 16:11:00', '2024-11-29 16:12:00',
#                '2024-11-29 16:15:00', '2024-11-29 16:16:00',
#                '2024-11-29 16:17:00', '2024-11-29 16:18:00',
#                '2024-11-29 16:20:00', '2024-11-29 16:22:00',
#                '2024-11-29 16:28:00', '2024-11-29 17:00:00'],
#               dtype='datetime64[ns]', length=12512, freq=None)

# %%
row_list = list()
for k in data["Time Series (1min)"].keys():
    daily_data = data["Time Series (1min)"][k]
    daily_dict = dict()
    daily_dict["time"] = k
    daily_dict["open"] = daily_data["1. open"]
    daily_dict["high"] = daily_data["2. high"]
    daily_dict["low"] = daily_data["3. low"]
    daily_dict["close"] = daily_data["4. close"]
    daily_dict["volume"] = daily_data["5. volume"]
    row_list.append(daily_dict)
data_df = pd.DataFrame.from_records(row_list)
data_df.set_index("time", inplace=True)
data_df.index = pd.to_datetime(data_df.index)
data_df.sort_index(ascending=True, axis=0, inplace=True)
data_df.to_csv(f"/home/bandee/projects/stockAnalyzer/trash_data/{symbol}_{month}.csv", index=True)

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey={ALPHA_API_KEY}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2025-01-03', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-01-03': {'1. open': '220.5500', '2. high': '223.6600', '3. low': '220.5500', '4. close': '222.6500', '5. volume': '3873578'}, '2025-01-02': {'1. open': '221.8200', '2. high': '222.4900', '3. low': '217.6000', '4. close': '219.9400', '5. volume': '2579498'}, '2024-12-31': {'1. open': '220.7200', '2. high': '221.0493', '3. low': '218.4400', '4. close': '219.8300', '5. volume': '2270512'}, '2024-12-30': {'1. open': '220.5400', '2. high': '221.5942', '3. low': '217.6523', '4. close': '220.2500', '5. volume': '2095565'}, '2024-12-27': {'1. open': '223.1400', '2. high': '224.4200', '3. low': '221.4054', '4. close': '222.7800', '5. volume': '1810760'}, '2024-12-26': {'1. open': '223.3100', '2. high': '225.4000', '3. low': '222.5500', '4. close': '224.8900', '5. volume': '3287238'}, '2024-12-24': {'1. open': '222.2700', '2. high': '224.4446', '3. low': '221.5428', '4. close': '224.4100', '5. volume': '1186216'}, '2024-12-23': {'1. open': '222.8100', '2. high': '223.7400', '3. low': '221.0800', '4. close': '221.9300', '5. volume': '2988137'}, '2024-12-20': {'1. open': '222.7300', '2. high': '227.6847', '3. low': '221.6800', '4. close': '223.3600', '5. volume': '12423200'}, '2024-12-19': {'1. open': '224.4200', '2. high': '226.2000', '3. low': '222.9800', '4. close': '223.9200', '5. volume': '4430120'}, '2024-12-18': {'1. open': '229.0350', '2. high': '229.0350', '3. low': '220.0300', '4. close': '220.1700', '5. volume': '4152517'}, '2024-12-17': {'1. open': '229.2300', '2. high': '230.2000', '3. low': '227.6200', '4. close': '228.9700', '5. volume': '3651346'}, '2024-12-16': {'1. open': '230.7300', '2. high': '231.0300', '3. low': '226.8800', '4. close': '229.3300', '5. volume': '3610257'}, '2024-12-13': {'1. open': '232.2500', '2. high': '233.7750', '3. low': '230.2600', '4. close': '230.8200', '5. volume': '2757683'}, '2024-12-12': {'1. open': '230.6600', '2. high': '233.8900', '3. low': '230.3800', '4. close': '232.2600', '5. volume': '4515741'}, '2024-12-11': {'1. open': '232.6900', '2. high': '233.0000', '3. low': '229.1300', '4. close': '230.1200', '5. volume': '3872680'}, '2024-12-10': {'1. open': '228.4000', '2. high': '234.3900', '3. low': '227.8000', '4. close': '231.7200', '5. volume': '4769531'}, '2024-12-09': {'1. open': '238.0000', '2. high': '239.3500', '3. low': '228.9100', '4. close': '230.0000', '5. volume': '4970449'}, '2024-12-06': {'1. open': '234.4300', '2. high': '238.3800', '3. low': '234.2200', '4. close': '238.0400', '5. volume': '4028430'}, '2024-12-05': {'1. open': '233.5500', '2. high': '236.5200', '3. low': '233.4600', '4. close': '234.7500', '5. volume': '4791116'}, '2024-12-04': {'1. open': '230.0000', '2. high': '233.7400', '3. low': '229.3500', '4. close': '233.4900', '5. volume': '4104195'}, '2024-12-03': {'1. open': '227.2400', '2. high': '229.1100', '3. low': '226.6700', '4. close': '229.0000', '5. volume': '3163815'}, '2024-12-02': {'1. open': '227.5000', '2. high': '228.3800', '3. low': '225.5100', '4. close': '227.3900', '5. volume': '2656181'}, '2024-11-29': {'1. open': '227.7500', '2. high': '230.3600', '3. low': '227.1900', '4. close': '227.4100', '5. volume': '2640253'}, '2024-11-27': {'1. open': '228.8300', '2. high': '229.1900', '3. low': '224.2700', '4. close': '226.9200', '5. volume': '2995121'}, '2024-11-26': {'1. open': '226.7300', '2. high': '228.9800', '3. low': '225.5115', '4. close': '228.8300', '5. volume': '4449543'}, '2024-11-25': {'1. open': '223.3500', '2. high': '226.4200', '3. low': '222.6500', '4. close': '226.1300', '5. volume': '7189260'}, '2024-11-22': {'1. open': '223.3500', '2. high': '227.2000', '3. low': '220.8900', '4. close': '222.9700', '5. volume': '5320740'}, '2024-11-21': {'1. open': '215.8100', '2. high': '222.6300', '3. low': '215.27 ...

# %%
pd.DataFrame.from_dict(data["Time Series (Daily)"], orient='index')
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2025-01-03  220.5500  223.6600  220.5500  222.6500   3873578
# 2025-01-02  221.8200  222.4900  217.6000  219.9400   2579498
# 2024-12-31  220.7200  221.0493  218.4400  219.8300   2270512
# 2024-12-30  220.5400  221.5942  217.6523  220.2500   2095565
# 2024-12-27  223.1400  224.4200  221.4054  222.7800   1810760
# ...              ...       ...       ...       ...       ...
# 2024-08-19  193.8400  195.5250  193.7150  194.7300   2361378
# 2024-08-16  193.5800  194.3500  192.8600  193.7800   2494472
# 2024-08-15  193.5100  194.2500  193.2800  193.9500   2471985
# 2024-08-14  191.1500  193.0900  190.7300  192.3200   1895114
# 2024-08-13  190.2900  191.3100  189.2100  190.9900   2178862
#
# [100 rows x 5 columns]

# %%
stickers = pd.read_csv("/home/bandee/projects/stockAnalyzer/configs/nasdaq_screener.csv")
stickers["Market Cap"] = stickers["Market Cap"].astype("Int64")
stickers["IPO Year"] = stickers["IPO Year"].astype("Int64")

stickers.columns = ['symbol', 'company_name', 'market_cap', 'country', 'ipo_year', 'sector', 'industry']
stickers.to_csv("/home/bandee/projects/stockAnalyzer/configs/nasdaq_screener.csv", index=False)
