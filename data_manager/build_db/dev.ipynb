# %%
import os
from dotenv import load_dotenv

import yfinance as yf

import yfinance as yf
import pandas as pd

# %%
stickers = pd.read_csv("/home/bandee/projects/stockAnalyzer/configs/nasdaq_screener.csv", index_col="Unnamed: 0")
stickers["Market Cap"] = stickers["Market Cap"].astype("Int64")
stickers["IPO Year"] = stickers["IPO Year"].astype("Int64")

stickers.columns
# Out:
# Index(['Symbol', 'Name', 'Market Cap', 'Country', 'IPO Year', 'Sector',
#        'Industry'],
#       dtype='object')

# %%
stickers.to_csv("/home/bandee/projects/stockAnalyzer/configs/nasdaq_screener.csv", index=False)

# %%
stickers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3862 entries, 0 to 3861
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      3861 non-null   object
#  1   Name        3862 non-null   object
#  2   Market Cap  3862 non-null   Int64
#  3   Country     3862 non-null   object
#  4   IPO Year    2230 non-null   Int64
#  5   Sector      3736 non-null   object
#  6   Industry    3735 non-null   object
# dtypes: Int64(2), object(5)
# memory usage: 248.9+ KB

# %%
from pathlib import Path
import sys

# Dynamically get the repository's root path
repo_root = Path(__file__).parent.parent.resolve()  # Go up one level from the script's location

# Add the repo root to sys.path
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# Example: Import a module from the repo
try:
    from your_module import some_function  # Replace with your actual module and function
    print("Module imported successfully!")
except ImportError as e:
    print(f"Error importing module: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       2 import sys
#       4 # Dynamically get the repository's root path
# ----> 5 repo_root = Path(__file__).parent.parent.resolve()  # Go up one level from the script's location
#       7 # Add the repo root to sys.path
#       8 if str(repo_root) not in sys.path:
#
# NameError: name '__file__' is not defined
